# %% [markdown]
# **Object Oriented Programming (OOP)**
# paradigm for thinking about things as objects vs running things as procedures (doing this to something-verb first); noun first - object first call something that does something to the object
#
# **application**
# works well with database models/schemas where each DB with a 1:1 ratio to class with fields within class = structured language use
#
# **class vs object**
# class is a wrapper in JS (not pure OOP - bolt on to keep C programmers happy)
#
# Class is the blueprint, Object is the instantiation of the class
#
# **example**
# store-->department(category)-->products(subcategory)
#
# store class:
# department
# logic to display the department category
# logic to navigate the department category
#
#
# department category class:
# logic to display the product details
# logic to navigate the product details
#
# product category class:
# logic to display the product price
# logic to navigate the product price
#
# clothes category product subclass:
# logic to display the product price
# logic to navigate the product price
# logic to display the product size and color
# logic to navigate the product size and color
#
# equipment category product subclass:
# logic to display the product price
# logic to navigate the product price
# logic to display the product durability
# logic to navigate the product durability
#
# products:
# hats
# clothes
# equipment

# %% [markdown]
# ![CS41_classes1.png](data:image/png;base64,...)

# %% [markdown]
# **Polymorphism**
# instanitiante a clothes object of the class clothes and is a product
# and is a clothes instance of a product class
# designed in this class but only acting within the instance it is called upon

# %% [markdown]
# ![CS41_classes_polymorphism.png](data:image/png;base64,...)

# %% [markdown]
# **use cases**
#
# OOPs - Object Relational Model (ORM) SQL/NOSQL Databases; automotive design
#
# Procedural - operating systems;
# lowlevel programming with abstractions

# %% [markdown]
# Store.py

# %% [markdown]
# __str__ - representation of a string
#
# __repr__ - representation of a class

# %%
from Department import Department
class Store:
  # attributes (field holding data)
  # name
  # departments (list)

  # methode to initialize class
  # runs everytime we make a new store
  # self is dealt with under the hood and we don't have to pass this in 
  def __init__(self, name='My Store', departments=[]):
      # you can set defaults
    self.name = name
    self.departments = departments


# print location of store object
# does this because we are calling 
# def __str__(self):
#   self.__repr__
# we haven't defined a str or repr method
# def __str__(self):
#   return 'This is a store'


def __str__(self):

  output = f"{self.name}"
   # for the index in the department in the enumerated(self.departments):
   # extracts the index and the physical thing 
  for i, dept in enumerate(self.departments):
    # concatonate more onto this
    # need a category name
    # all items must be strings
    output += " " + str(i +1) + ". " + dept + "\n"

    #output += f

    return output

def __repr__(self):
 return f'Store("{self.name},{self.departments})'


# create an instance of store class 
my_store = Store("Bob's Emporium", [Department('clothes'), Department('tools'), Department('costmetics'), Department('electronics')])

# make a varible to hold users choice
choice = 0
while choice != len(my_store.departments) + 1:
  # print out the menu
  print(my_store) 

  # request input from the user
  choice = input("Select the department you wish to enter by number: ")
  if choice == len(my_store.department) + 1:
     print(f'Thank you for shopping at {my_store.name}')
     break

# print the user selection/choice
print(f'{my-store.departments[int(choice)-1]}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-f5bbe80ba202> in <module>()
# ----> 1 from Department import Department
#       2 class Store:
#       3   # attributes (field holding data)
#       4   # name
#       5   # departments (list)
#
# ModuleNotFoundError: No module named 'Department'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Departments.py

# %%
class Department:
  def __init__(self, name):
    self.name = name

  def __str__(self):
    return f'No products found in {self.name}'
