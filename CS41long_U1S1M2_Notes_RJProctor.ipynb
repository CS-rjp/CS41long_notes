# %% [markdown]
# ![CS41_super_init.png](data:image/png;base64,...)

# %% [markdown]
# Store.py

# %%
from Department import Department
class Store:
  # attributes (field holding data)
  # name
  # departments (list)

  # methode to initialize class
  # runs everytime we make a new store
  # self is dealt with under the hood and we don't have to pass this in 
  def __init__(self, name='My Store', departments=[]):
      # you can set defaults
    self.name = name
    self.departments = departments


# print location of store object
# does this because we are calling 
# def __str__(self):
#   self.__repr__
# we haven't defined a str or repr method
# def __str__(self):
#   return 'This is a store'


def __str__(self):

  output = f"{self.name}"
   # for the index in the department in the enumerated(self.departments):
   # extracts the index and the physical thing 
  for i, dept in enumerate(self.departments):
    # concatonate more onto this
    # need a category name
    # all items must be strings
    output += " " + str(i +1) + ". " + dept + "\n"

    #output += f

    return output

def __repr__(self):
 return f'Store("{self.name},{self.departments})'


# create an instance of store class 
my_store = Store("Bob's Emporium", [Department('clothes'), Department('tools'), Department('costmetics'), Department('electronics')])

# make a varible to hold users choice
choice = 0
while choice != len(my_store.departments) + 1:
  # print out the menu
  print(my_store) 

  # request input from the user
  choice = input("Select the department you wish to enter by number: ")
  if choice == len(my_store.department) + 1:
     print(f'Thank you for shopping at {my_store.name}')
     break

# print the user selection/choice
print(f'{my-store.departments[int(choice)-1]}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f5bbe80ba202> in <module>()
# ----> 1 from Department import Department
#       2 class Store:
#       3   # attributes (field holding data)
#       4   # name
#       5   # departments (list)
#
# ModuleNotFoundError: No module named 'Department'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Department.py

# %%
class Department:
  """
  department has_many products - composition
  """
  def __init__(self, name):
    self.name = name

  def __str__(self):
    return f'No products found in {self.name}'

# %% [markdown]
# Product.py

# %%
class Product:
  def __init__(self, name, price):
    self.name = name
    self.price = price

  def __str__(self):
    return f'{self.name} /t$ {self.price}'

# %% [markdown]
# Clothing.py

# %%
from Product import Product

class Clothing(Product):
  """
  clothing is_a product - polymorphism
  """
  def __init__(self, name, price, size, color):
    super().__init__(name, price)
    self.size = size
    self.color = color

  def __str__(self):
    return f'{super.__str__()} come in {self.size}, {self.color}. '
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-c3dc003523c1> in <module>()
# ----> 1 from Product import Product
#       2
#       3 class Clothing(Product):
#       4   """
#       5   clothing is_a product - polymorphism
#
# ModuleNotFoundError: No module named 'Product'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Tool.py

# %%
from Product import Product

class Tool(Product):
  """
  tool is_a product - polymorphism
  """
  def __init__(self, name, price, category):
    super()__init__(name, price)
    self.category = category

  def __str__(self):
    return f'{super.__str__()} is a {self.category}. '
# Out:
#   File "<ipython-input-9-e401b9343776>", line 8
#     super()__init__.(name, price)
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# Electronic.py

# %%
from Product import Product

class Electronic(Product):
  """
  electronic is_a product - polymorphism
  """
  def __init__(self, name, price, power_rating):
    super()__init__(name, price)
    self.power_rating = power_rating

  def __str__(self):
    return f'{super.__str__()} is rated at {self.power_rating}. '
